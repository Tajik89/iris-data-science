# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_frame = pd.read_csv('iris_data.csv')

# %%
data_frame
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
# Missing data

# %%
for i in data_frame :
    data_frame[data_frame[i].notna()]

# %%
# outlier data

# %%
data_frame.boxplot()
plt.show()

# %%
df_numeric = data_frame.select_dtypes(include=['float64', 'int64'])

Q1 = df_numeric.quantile(0.25)
Q3 = df_numeric.quantile(0.75)

IQR = Q3 - Q1

data_frame = data_frame[~((df_numeric < (Q1 - 1.5 * IQR)) | (df_numeric > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
data_frame.boxplot()
plt.show()

# %%
# Duplicate data

# %%
data_frame = data_frame.drop_duplicates()

# %%
data_frame.plot()
plt.show()

# %%
# cleaning data by TAKING
# Tajik89.github.io
# github.com/Tajik89
